# %% [markdown]
# ### Unzip Dataset
# Unzips the provided dataset archive for the hiring assessment.

# %%
# !unzip -q "/content/shl-intern-hiring-assessment-2025.zip" -d "/content/"

# %% [markdown]
# ### Install Required Libraries
# Installs necessary Python libraries including `openai-whisper` for speech-to-text, `nltk` for natural language processing, `scikit-learn` for machine learning, and `librosa` for audio analysis.

# %%
# !pip install -q openai-whisper nltk scikit-learn librosa
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 803.2/803.2 kB 11.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.5/170.5 MB 3.5 MB/s eta 0:00:00
#   Building wheel for openai-whisper (pyproject.toml) ... done

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/content/dataset'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /content/dataset/csvs/test.csv
# /content/dataset/csvs/train.csv
# /content/dataset/audios/train/audio_40_2.wav
# /content/dataset/audios/train/audio_353.wav
# /content/dataset/audios/train/audio_347.wav
# /content/dataset/audios/train/audio_42.wav
# /content/dataset/audios/train/audio_64_2.wav
# /content/dataset/audios/train/audio_89.wav
# /content/dataset/audios/train/audio_308.wav
# /content/dataset/audios/train/audio_20.wav
# /content/dataset/audios/train/audio_171.wav
# /content/dataset/audios/train/audio_245.wav
# /content/dataset/audios/train/audio_168.wav
# /content/dataset/audios/train/audio_77_2.wav
# /content/dataset/audios/train/audio_224.wav
# /content/dataset/audios/train/audio_147.wav
# /content/dataset/audios/train/audio_34_2.wav
# /content/dataset/audios/train/audio_65.wav
# /content/dataset/audios/train/audio_83.wav
# /content/dataset/audios/train/audio_53.wav
# /content/dataset/audios/train/audio_275.wav
# /content/dataset/audios/train/audio_79.wav
# /content/dataset/audios/train/audio_130.wav
# /content/dataset/audios/train/audio_188.wav
# /content/dataset/audios/train/audio_256_2.wav
# /content/dataset/audios/train/audio_256.wav
# /content/dataset/audios/train/audio_257.wav
# /content/dataset/audios/train/audio_322.wav
# /content/dataset/audios/train/audio_238.wav
# /content/dataset/audios/train/audio_94.wav
# /content/dataset/audios/train/audio_155.wav
# /content/dataset/audios/train/audio_220.wav
# /content/dataset/audios/train/audio_362.wav
# /content/dataset/audios/train/audio_63.wav
# /content/dataset/audios/train/audio_320.wav
# /content/dataset/audios/train/audio_7.wav
# /content/dataset/audios/train/audio_11.wav
# /content/dataset/audios/train/audio_88.wav
# /content/dataset/audios/train/audio_226.wav
# /content/dataset/audios/train/audio_179.wav
# /content/dataset/audios/train/audio_222.wav
# /content/dataset/audios/train/audio_226_2.wav
# /content/dataset/audios/train/audio_351.wav
# /content/dataset/audios/train/audio_206.wav
# /content/dataset/audios/train/audio_111.wav
# /content/dataset/audios/train/audio_176.wav
# /content/dataset/audios/train/audio_196.wav
# /content/dataset/audios/train/audio_97.wav
# /content/dataset/audios/train/audio_61.wav
# /content/dataset/audios/train/audio_270.wav
# /content/dataset/audios/train/audio_152.wav
# /content/dataset/audios/train/audio_109.wav
# /content/dataset/audios/train/audio_82.wav
# /content/dataset/audios/train/audio_26.wav
# /content/dataset/audios/train/audio_336_2.wav
# /content/dataset/audios/train/audio_210.wav
# /content/dataset/audios/train/audio_242.wav
# /content/dataset/audios/train/audio_182.wav
# /content/dataset/audios/train/audio_252.wav
# /content/dataset/audios/train/audio_327.wav
# /content/dataset/audios/train/audio_37.wav
# /content/dataset/audios/train/audio_144.wav
# /content/dataset/audios/train/audio_69.wav
# /content/dataset/audios/train/audio_30.wav
# /content/dataset/audios/train/audio_247.wav
# /content/dataset/audios/train/audio_197.wav
# /content/dataset/audios/train/audio_181.wav
# /content/dataset/audios/train/audio_3.wav
# /content/dataset/audios/train/audio_17.wav
# /content/dataset/audios/train/audio_44.wav
# /content/dataset/audios/train/audio_194_2.wav
# /content/dataset/audios/train/audio_201.wav
# /content/dataset/audios/train/audio_142.wav
# /content/dataset/audios/train/audio_261.wav
# /content/dataset/audios/train/audio_21.wav
# /content/dataset/audios/train/audio_102_2.wav
# /content/dataset/audios/train/audio_92.wav
# /content/dataset/audios/train/audio_230.wav
# /content/dataset/audios/train/audio_228.wav
# /content/dataset/audios/train/audio_98.wav
# /content/dataset/audios/train/audio_318.wav
# /content/dataset/audios/train/audio_326.wav
# /content/dataset/audios/train/audio_137.wav
# /content/dataset/audios/train/audio_295.wav
# /content/dataset/audios/train/audio_191.wav
# /content/dataset/audios/train/audio_70.wav
# /content/dataset/audios/train/audio_328.wav
# /content/dataset/audios/train/audio_234.wav
# /content/dataset/audios/train/audio_118.wav
# /content/dataset/audios/train/audio_159.wav
# /content/dataset/audios/train/audio_344.wav
# /content/dataset/audios/train/audio_56_2.wav
# /content/dataset/audios/train/audio_333.wav
# /content/dataset/audios/train/audio_108.wav
# /content/dataset/audios/train/audio_341.wav
# /content/dataset/audios/train/audio_200.wav
# /content/dataset/audios/train/audio_122.wav
# /content/dataset/audios/train/audio_368.wav
# /content/dataset/audios/train/audio_136.wav
# /content/dataset/audios/train/audio_279_2.wav
# /content/dataset/audios/train/audio_267.wav
# /content/dataset/audios/train/audio_5.wav
# /content/dataset/audios/train/audio_114.wav
# /content/dataset/audios/train/audio_193.wav
# /content/dataset/audios/train/audio_358.wav
# /content/dataset/audios/train/audio_129.wav
# /content/dataset/audios/train/audio_281.wav
# /content/dataset/audios/train/audio_246.wav
# /content/dataset/audios/train/audio_340.wav
# /content/dataset/audios/train/audio_205.wav
# /content/dataset/audios/train/audio_19.wav
# /content/dataset/audios/train/audio_262.wav
# /content/dataset/audios/train/audio_90.wav
# /content/dataset/audios/train/audio_258.wav
# /content/dataset/audios/train/audio_361.wav
# /content/dataset/audios/train/audio_265.wav
# /content/dataset/audios/train/audio_302.wav
# /content/dataset/audios/train/audio_216.wav
# /content/dataset/audios/train/audio_133.wav
# /content/dataset/audios/train/audio_95.wav
# /content/dataset/audios/train/audio_38.wav
# /content/dataset/audios/train/audio_294.wav
# /content/dataset/audios/train/audio_167.wav
# /content/dataset/audios/train/audio_153.wav
# /content/dataset/audios/train/audio_164.wav
# /content/dataset/audios/train/audio_243.wav
# /content/dataset/audios/train/audio_268.wav
# /content/dataset/audios/train/audio_195_2.wav
# /content/dataset/audios/train/audio_289.wav
# /content/dataset/audios/train/audio_337.wav
# /content/dataset/audios/train/audio_292.wav
# /content/dataset/audios/train/audio_260.wav
# /content/dataset/audios/train/audio_128.wav
# /content/dataset/audios/train/audio_365.wav
# /content/dataset/audios/train/audio_132.wav
# /content/dataset/audios/train/audio_366.wav
# /content/dataset/audios/train/audio_356.wav
# /content/dataset/audios/train/audio_223.wav
# /content/dataset/audios/train/audio_43_2.wav
# /content/dataset/audios/train/audio_310.wav
# /content/dataset/audios/train/audio_163.wav
# /content/dataset/audios/train/audio_264.wav
# /content/dataset/audios/train/audio_306_2.wav
# /content/dataset/audios/train/audio_296.wav
# /content/dataset/audios/train/audio_29.wav
# /content/dataset/audios/train/audio_204.wav
# /content/dataset/audios/train/audio_126.wav
# /content/dataset/audios/train/audio_263.wav
# /content/dataset/audios/train/audio_301.wav
# /content/dataset/audios/train/audio_319.wav
# /content/dataset/audios/train/audio_1.wav
# /content/dataset/audios/train/audio_109_2.wav
# /content/dataset/audios/train/audio_46.wav
# /content/dataset/audios/train/audio_321.wav
# /content/dataset/audios/train/audio_185.wav
# /content/dataset/audios/train/audio_39.wav
# /content/dataset/audios/train/audio_158.wav
# /content/dataset/audios/train/audio_287.wav
# /content/dataset/audios/train/audio_272.wav
# /content/dataset/audios/train/audio_149.wav
# /content/dataset/audios/train/audio_304.wav
# /content/dataset/audios/train/audio_237.wav
# /content/dataset/audios/train/audio_286.wav
# /content/dataset/audios/train/audio_18.wav
# /content/dataset/audios/train/audio_313.wav
# /content/dataset/audios/train/audio_312.wav
# /content/dataset/audios/train/audio_208.wav
# /content/dataset/audios/train/audio_140.wav
# /content/dataset/audios/train/audio_232.wav
# /content/dataset/audios/train/audio_198.wav
# /content/dataset/audios/train/audio_16.wav
# /content/dataset/audios/train/audio_74.wav
# /content/dataset/audios/train/audio_184.wav
# /content/dataset/audios/train/audio_154.wav
# /content/dataset/audios/train/audio_87.wav
# /content/dataset/audios/train/audio_12.wav
# /content/dataset/audios/train/audio_211.wav
# /content/dataset/audios/train/audio_364.wav
# /content/dataset/audios/train/audio_141.wav
# /content/dataset/audios/train/audio_360.wav
# /content/dataset/audios/train/audio_156_2.wav
# /content/dataset/audios/train/audio_238_2.wav
# /content/dataset/audios/train/audio_96.wav
# /content/dataset/audios/train/audio_80.wav
# /content/dataset/audios/train/audio_131.wav
# /content/dataset/audios/train/audio_317.wav
# /content/dataset/audios/train/audio_101.wav
# /content/dataset/audios/train/audio_253.wav
# /content/dataset/audios/train/audio_162.wav
# /content/dataset/audios/train/audio_120_2.wav
# /content/dataset/audios/train/audio_124.wav
# /content/dataset/audios/train/audio_192.wav
# /content/dataset/audios/train/audio_103.wav
# /content/dataset/audios/train/audio_315_2.wav
# /content/dataset/audios/train/audio_14.wav
# /content/dataset/audios/train/audio_151.wav
# /content/dataset/audios/train/audio_241.wav
# /content/dataset/audios/train/audio_31.wav
# /content/dataset/audios/train/audio_115_2.wav
# /content/dataset/audios/train/audio_116.wav
# /content/dataset/audios/train/audio_330.wav
# /content/dataset/audios/train/audio_78.wav
# /content/dataset/audios/train/audio_324.wav
# /content/dataset/audios/train/audio_311.wav
# /content/dataset/audios/train/audio_86.wav
# /content/dataset/audios/train/audio_10.wav
# /content/dataset/audios/train/audio_298.wav
# /content/dataset/audios/train/audio_249.wav
# /content/dataset/audios/train/audio_10_2.wav
# /content/dataset/audios/train/audio_195.wav
# /content/dataset/audios/train/audio_43.wav
# /content/dataset/audios/train/audio_283.wav
# /content/dataset/audios/train/audio_181_2.wav
# /content/dataset/audios/train/audio_35.wav
# /content/dataset/audios/train/audio_110.wav
# /content/dataset/audios/train/audio_325.wav
# /content/dataset/audios/train/audio_189.wav
# /content/dataset/audios/train/audio_232_2.wav
# /content/dataset/audios/train/audio_280.wav
# /content/dataset/audios/train/audio_55.wav
# /content/dataset/audios/train/audio_27.wav
# /content/dataset/audios/train/audio_314.wav
# /content/dataset/audios/train/audio_52.wav
# /content/dataset/audios/train/audio_47.wav
# /content/dataset/audios/train/audio_24.wav
# /content/dataset/audios/train/audio_276.wav
# /content/dataset/audios/train/audio_120.wav
# /content/dataset/audios/train/audio_36.wav
# /content/dataset/audios/train/audio_215.wav
# /content/dataset/audios/train/audio_213.wav
# /content/dataset/audios/train/audio_121.wav
# /content/dataset/audios/train/audio_315.wav
# /content/dataset/audios/train/audio_346.wav
# /content/dataset/audios/train/audio_23.wav
# /content/dataset/audios/train/audio_16_2.wav
# /content/dataset/audios/train/audio_307.wav
# /content/dataset/audios/train/audio_186.wav
# /content/dataset/audios/train/audio_166.wav
# /content/dataset/audios/train/audio_64.wav
# /content/dataset/audios/train/audio_25.wav
# /content/dataset/audios/train/audio_316.wav
# /content/dataset/audios/train/audio_48.wav
# /content/dataset/audios/train/audio_323.wav
# /content/dataset/audios/train/audio_146.wav
# /content/dataset/audios/train/audio_154_2.wav
# /content/dataset/audios/train/audio_99.wav
# /content/dataset/audios/train/audio_357.wav
# /content/dataset/audios/train/audio_134.wav
# /content/dataset/audios/train/audio_231.wav
# /content/dataset/audios/train/audio_85.wav
# /content/dataset/audios/train/audio_289_2.wav
# /content/dataset/audios/train/audio_54.wav
# /content/dataset/audios/train/audio_240.wav
# /content/dataset/audios/train/audio_235.wav
# /content/dataset/audios/train/audio_240_2.wav
# /content/dataset/audios/train/audio_26_2.wav
# /content/dataset/audios/train/audio_123.wav
# /content/dataset/audios/train/audio_282.wav
# /content/dataset/audios/train/audio_84.wav
# /content/dataset/audios/train/audio_160.wav
# /content/dataset/audios/train/audio_331.wav
# /content/dataset/audios/train/audio_248.wav
# /content/dataset/audios/train/audio_170.wav
# /content/dataset/audios/train/audio_178.wav
# /content/dataset/audios/train/audio_91.wav
# /content/dataset/audios/train/audio_117.wav
# /content/dataset/audios/train/audio_66.wav
# /content/dataset/audios/train/audio_334.wav
# /content/dataset/audios/train/audio_350.wav
# /content/dataset/audios/train/audio_214.wav
# /content/dataset/audios/train/audio_106.wav
# /content/dataset/audios/train/audio_288.wav
# /content/dataset/audios/train/audio_369_2.wav
# /content/dataset/audios/train/audio_218.wav
# /content/dataset/audios/train/audio_254.wav
# /content/dataset/audios/train/audio_234_2.wav
# /content/dataset/audios/train/audio_360_2.wav
# /content/dataset/audios/train/audio_58_2.wav
# /content/dataset/audios/train/audio_76.wav
# /content/dataset/audios/train/audio_332.wav
# /content/dataset/audios/train/audio_183.wav
# /content/dataset/audios/train/audio_156.wav
# /content/dataset/audios/train/audio_274.wav
# /content/dataset/audios/train/audio_173.wav
# /content/dataset/audios/train/audio_303.wav
# /content/dataset/audios/train/audio_22.wav
# /content/dataset/audios/train/audio_41.wav
# /content/dataset/audios/train/audio_284.wav
# /content/dataset/audios/train/audio_33.wav
# /content/dataset/audios/train/audio_329.wav
# /content/dataset/audios/train/audio_15.wav
# /content/dataset/audios/train/audio_290.wav
# /content/dataset/audios/train/audio_359.wav
# /content/dataset/audios/train/audio_40.wav
# /content/dataset/audios/train/audio_139.wav
# /content/dataset/audios/train/audio_73_2.wav
# /content/dataset/audios/train/audio_112.wav
# /content/dataset/audios/train/audio_250.wav
# /content/dataset/audios/train/audio_372.wav
# /content/dataset/audios/train/audio_251.wav
# /content/dataset/audios/train/audio_165.wav
# /content/dataset/audios/train/audio_177.wav
# /content/dataset/audios/train/audio_212.wav
# /content/dataset/audios/train/audio_9.wav
# /content/dataset/audios/train/audio_143.wav
# /content/dataset/audios/train/audio_56.wav
# /content/dataset/audios/train/audio_348.wav
# /content/dataset/audios/train/audio_8.wav
# /content/dataset/audios/train/audio_81.wav
# /content/dataset/audios/train/audio_107.wav
# /content/dataset/audios/train/audio_1_2.wav
# /content/dataset/audios/train/audio_338.wav
# /content/dataset/audios/train/audio_349.wav
# /content/dataset/audios/train/audio_207.wav
# /content/dataset/audios/train/audio_6.wav
# /content/dataset/audios/train/audio_119.wav
# /content/dataset/audios/train/audio_2.wav
# /content/dataset/audios/train/audio_217.wav
# /content/dataset/audios/train/audio_4.wav
# /content/dataset/audios/train/audio_75.wav
# /content/dataset/audios/train/audio_138_2.wav
# /content/dataset/audios/train/audio_135.wav
# /content/dataset/audios/train/audio_138.wav
# /content/dataset/audios/train/audio_309.wav
# /content/dataset/audios/train/audio_169.wav
# /content/dataset/audios/train/audio_68.wav
# /content/dataset/audios/train/audio_105.wav
# /content/dataset/audios/train/audio_300.wav
# /content/dataset/audios/train/audio_345.wav
# /content/dataset/audios/train/audio_367.wav
# /content/dataset/audios/train/audio_145.wav
# /content/dataset/audios/train/audio_305.wav
# /content/dataset/audios/train/audio_180.wav
# /content/dataset/audios/train/audio_73.wav
# /content/dataset/audios/train/audio_125.wav
# /content/dataset/audios/train/audio_34.wav
# /content/dataset/audios/train/audio_342.wav
# /content/dataset/audios/train/audio_370.wav
# /content/dataset/audios/train/audio_306.wav
# /content/dataset/audios/train/audio_233.wav
# /content/dataset/audios/train/audio_13.wav
# /content/dataset/audios/train/audio_209.wav
# /content/dataset/audios/train/audio_352.wav
# /content/dataset/audios/train/audio_72.wav
# /content/dataset/audios/train/audio_244.wav
# /content/dataset/audios/train/audio_150.wav
# /content/dataset/audios/train/audio_363.wav
# /content/dataset/audios/train/audio_269.wav
# /content/dataset/audios/train/audio_104.wav
# /content/dataset/audios/train/audio_102.wav
# /content/dataset/audios/train/audio_194.wav
# /content/dataset/audios/train/audio_336.wav
# /content/dataset/audios/train/audio_335.wav
# /content/dataset/audios/train/audio_157.wav
# /content/dataset/audios/train/audio_236.wav
# /content/dataset/audios/train/audio_174.wav
# /content/dataset/audios/train/audio_219.wav
# /content/dataset/audios/train/audio_60.wav
# /content/dataset/audios/train/audio_355.wav
# /content/dataset/audios/train/audio_100.wav
# /content/dataset/audios/train/audio_229.wav
# /content/dataset/audios/train/audio_271.wav
# /content/dataset/audios/train/audio_369.wav
# /content/dataset/audios/train/audio_339.wav
# /content/dataset/audios/train/audio_172.wav
# /content/dataset/audios/train/audio_62.wav
# /content/dataset/audios/train/audio_190.wav
# /content/dataset/audios/train/audio_127.wav
# /content/dataset/audios/train/audio_371.wav
# /content/dataset/audios/train/audio_127_2.wav
# /content/dataset/audios/train/audio_50.wav
# /content/dataset/audios/train/audio_51.wav
# /content/dataset/audios/train/audio_225.wav
# /content/dataset/audios/train/audio_278.wav
# /content/dataset/audios/train/audio_175.wav
# /content/dataset/audios/train/audio_279.wav
# /content/dataset/audios/train/audio_266.wav
# /content/dataset/audios/train/audio_343.wav
# /content/dataset/audios/train/audio_273.wav
# /content/dataset/audios/train/audio_255.wav
# /content/dataset/audios/train/audio_148.wav
# /content/dataset/audios/train/audio_227.wav
# /content/dataset/audios/train/audio_161.wav
# /content/dataset/audios/train/audio_59.wav
# /content/dataset/audios/train/audio_115.wav
# /content/dataset/audios/train/audio_293.wav
# /content/dataset/audios/train/audio_28.wav
# /content/dataset/audios/train/audio_199.wav
# /content/dataset/audios/train/audio_113.wav
# /content/dataset/audios/train/audio_239.wav
# /content/dataset/audios/train/audio_58.wav
# /content/dataset/audios/train/audio_328_2.wav
# /content/dataset/audios/train/audio_221.wav
# /content/dataset/audios/train/audio_203.wav
# /content/dataset/audios/train/audio_202.wav
# /content/dataset/audios/train/audio_93.wav
# /content/dataset/audios/train/audio_297.wav
# /content/dataset/audios/train/audio_77.wav
# /content/dataset/audios/train/audio_71.wav
# /content/dataset/audios/train/audio_49.wav
# /content/dataset/audios/train/audio_299.wav
# /content/dataset/audios/train/audio_32.wav
# /content/dataset/audios/train/audio_354.wav
# /content/dataset/audios/train/audio_187.wav
# /content/dataset/audios/train/audio_57.wav
# /content/dataset/audios/train/audio_285.wav
# /content/dataset/audios/train/audio_277.wav
# /content/dataset/audios/train/audio_259.wav
# /content/dataset/audios/train/audio_291.wav
# /content/dataset/audios/train/audio_67.wav
# /content/dataset/audios/train/audio_45.wav
# /content/dataset/audios/test/audio_42.wav
# /content/dataset/audios/test/audio_89.wav
# /content/dataset/audios/test/audio_20.wav
# /content/dataset/audios/test/audio_25_1.wav
# /content/dataset/audios/test/audio_147.wav
# /content/dataset/audios/test/audio_65.wav
# /content/dataset/audios/test/audio_83.wav
# /content/dataset/audios/test/audio_53.wav
# /content/dataset/audios/test/audio_79.wav
# /content/dataset/audios/test/audio_130.wav
# /content/dataset/audios/test/audio_94.wav
# /content/dataset/audios/test/audio_155.wav
# /content/dataset/audios/test/audio_16_1.wav
# /content/dataset/audios/test/audio_63.wav
# /content/dataset/audios/test/audio_7.wav
# /content/dataset/audios/test/audio_11.wav
# /content/dataset/audios/test/audio_67_1.wav
# /content/dataset/audios/test/audio_88.wav
# /content/dataset/audios/test/audio_111.wav
# /content/dataset/audios/test/audio_97.wav
# /content/dataset/audios/test/audio_61.wav
# /content/dataset/audios/test/audio_152.wav
# /content/dataset/audios/test/audio_109.wav
# /content/dataset/audios/test/audio_82.wav
# /content/dataset/audios/test/audio_26.wav
# /content/dataset/audios/test/audio_17_1.wav
# /content/dataset/audios/test/audio_37.wav
# /content/dataset/audios/test/audio_144.wav
# /content/dataset/audios/test/audio_69.wav
# /content/dataset/audios/test/audio_30.wav
# /content/dataset/audios/test/audio_140_1.wav
# /content/dataset/audios/test/audio_3.wav
# /content/dataset/audios/test/audio_17.wav
# /content/dataset/audios/test/audio_44.wav
# /content/dataset/audios/test/audio_142.wav
# /content/dataset/audios/test/audio_21.wav
# /content/dataset/audios/test/audio_92.wav
# /content/dataset/audios/test/audio_98.wav
# /content/dataset/audios/test/audio_137.wav
# /content/dataset/audios/test/audio_70.wav
# /content/dataset/audios/test/audio_118.wav
# /content/dataset/audios/test/audio_159.wav
# /content/dataset/audios/test/audio_108.wav
# /content/dataset/audios/test/audio_122.wav
# /content/dataset/audios/test/audio_136.wav
# /content/dataset/audios/test/audio_5.wav
# /content/dataset/audios/test/audio_114.wav
# /content/dataset/audios/test/audio_146_1.wav
# /content/dataset/audios/test/audio_129.wav
# /content/dataset/audios/test/audio_19.wav
# /content/dataset/audios/test/audio_90.wav
# /content/dataset/audios/test/audio_133.wav
# /content/dataset/audios/test/audio_95.wav
# /content/dataset/audios/test/audio_38.wav
# /content/dataset/audios/test/audio_153.wav
# /content/dataset/audios/test/audio_164.wav
# /content/dataset/audios/test/audio_128.wav
# /content/dataset/audios/test/audio_132.wav
# /content/dataset/audios/test/audio_163.wav
# /content/dataset/audios/test/audio_29.wav
# /content/dataset/audios/test/audio_126.wav
# /content/dataset/audios/test/audio_32_1.wav
# /content/dataset/audios/test/audio_10_1.wav
# /content/dataset/audios/test/audio_1.wav
# /content/dataset/audios/test/audio_46.wav
# /content/dataset/audios/test/audio_106_1.wav
# /content/dataset/audios/test/audio_39.wav
# /content/dataset/audios/test/audio_158.wav
# /content/dataset/audios/test/audio_149.wav
# /content/dataset/audios/test/audio_18.wav
# /content/dataset/audios/test/audio_140.wav
# /content/dataset/audios/test/audio_16.wav
# /content/dataset/audios/test/audio_74.wav
# /content/dataset/audios/test/audio_154.wav
# /content/dataset/audios/test/audio_87.wav
# /content/dataset/audios/test/audio_12.wav
# /content/dataset/audios/test/audio_141.wav
# /content/dataset/audios/test/audio_96.wav
# /content/dataset/audios/test/audio_80.wav
# /content/dataset/audios/test/audio_131.wav
# /content/dataset/audios/test/audio_101.wav
# /content/dataset/audios/test/audio_162.wav
# /content/dataset/audios/test/audio_96_1.wav
# /content/dataset/audios/test/audio_124.wav
# /content/dataset/audios/test/audio_103.wav
# /content/dataset/audios/test/audio_14.wav
# /content/dataset/audios/test/audio_151.wav
# /content/dataset/audios/test/audio_31.wav
# /content/dataset/audios/test/audio_116.wav
# /content/dataset/audios/test/audio_78.wav
# /content/dataset/audios/test/audio_61_1.wav
# /content/dataset/audios/test/audio_86.wav
# /content/dataset/audios/test/audio_10.wav
# /content/dataset/audios/test/audio_43.wav
# /content/dataset/audios/test/audio_35.wav
# /content/dataset/audios/test/audio_110.wav
# /content/dataset/audios/test/audio_55.wav
# /content/dataset/audios/test/audio_27.wav
# /content/dataset/audios/test/audio_76_1.wav
# /content/dataset/audios/test/audio_52.wav
# /content/dataset/audios/test/audio_135_1.wav
# /content/dataset/audios/test/audio_47.wav
# /content/dataset/audios/test/audio_24.wav
# /content/dataset/audios/test/audio_120.wav
# /content/dataset/audios/test/audio_56_1.wav
# /content/dataset/audios/test/audio_36.wav
# /content/dataset/audios/test/audio_121.wav
# /content/dataset/audios/test/audio_19_1.wav
# /content/dataset/audios/test/audio_132_1.wav
# /content/dataset/audios/test/audio_23.wav
# /content/dataset/audios/test/audio_57_1.wav
# /content/dataset/audios/test/audio_64.wav
# /content/dataset/audios/test/audio_25.wav
# /content/dataset/audios/test/audio_48.wav
# /content/dataset/audios/test/audio_146.wav
# /content/dataset/audios/test/audio_20_1.wav
# /content/dataset/audios/test/audio_99.wav
# /content/dataset/audios/test/audio_134.wav
# /content/dataset/audios/test/audio_158_1.wav
# /content/dataset/audios/test/audio_85.wav
# /content/dataset/audios/test/audio_133_1.wav
# /content/dataset/audios/test/audio_54.wav
# /content/dataset/audios/test/audio_123.wav
# /content/dataset/audios/test/audio_84.wav
# /content/dataset/audios/test/audio_160.wav
# /content/dataset/audios/test/audio_91.wav
# /content/dataset/audios/test/audio_136_1.wav
# /content/dataset/audios/test/audio_156_1.wav
# /content/dataset/audios/test/audio_117.wav
# /content/dataset/audios/test/audio_66.wav
# /content/dataset/audios/test/audio_106.wav
# /content/dataset/audios/test/audio_13_1.wav
# /content/dataset/audios/test/audio_76.wav
# /content/dataset/audios/test/audio_161_1.wav
# /content/dataset/audios/test/audio_156.wav
# /content/dataset/audios/test/audio_102_1.wav
# /content/dataset/audios/test/audio_22.wav
# /content/dataset/audios/test/audio_41.wav
# /content/dataset/audios/test/audio_33.wav
# /content/dataset/audios/test/audio_15.wav
# /content/dataset/audios/test/audio_40.wav
# /content/dataset/audios/test/audio_139.wav
# /content/dataset/audios/test/audio_112.wav
# /content/dataset/audios/test/audio_9.wav
# /content/dataset/audios/test/audio_143.wav
# /content/dataset/audios/test/audio_56.wav
# /content/dataset/audios/test/audio_8.wav
# /content/dataset/audios/test/audio_81.wav
# /content/dataset/audios/test/audio_107.wav
# /content/dataset/audios/test/audio_79_1.wav
# /content/dataset/audios/test/audio_6.wav
# /content/dataset/audios/test/audio_119.wav
# /content/dataset/audios/test/audio_2.wav
# /content/dataset/audios/test/audio_4.wav
# /content/dataset/audios/test/audio_75.wav
# /content/dataset/audios/test/audio_135.wav
# /content/dataset/audios/test/audio_138.wav
# /content/dataset/audios/test/audio_31_1.wav
# /content/dataset/audios/test/audio_68.wav
# /content/dataset/audios/test/audio_105.wav
# /content/dataset/audios/test/audio_116_1.wav
# /content/dataset/audios/test/audio_145.wav
# /content/dataset/audios/test/audio_73.wav
# /content/dataset/audios/test/audio_125.wav
# /content/dataset/audios/test/audio_34.wav
# /content/dataset/audios/test/audio_13.wav
# /content/dataset/audios/test/audio_72.wav
# /content/dataset/audios/test/audio_150.wav
# /content/dataset/audios/test/audio_104.wav
# /content/dataset/audios/test/audio_102.wav
# /content/dataset/audios/test/audio_157.wav
# /content/dataset/audios/test/audio_60.wav
# /content/dataset/audios/test/audio_100.wav
# /content/dataset/audios/test/audio_30_1.wav
# /content/dataset/audios/test/audio_62.wav
# /content/dataset/audios/test/audio_99_1.wav
# /content/dataset/audios/test/audio_127.wav
# /content/dataset/audios/test/audio_50.wav
# /content/dataset/audios/test/audio_51.wav
# /content/dataset/audios/test/audio_148.wav
# /content/dataset/audios/test/audio_161.wav
# /content/dataset/audios/test/audio_59.wav
# /content/dataset/audios/test/audio_115.wav
# /content/dataset/audios/test/audio_28.wav
# /content/dataset/audios/test/audio_113.wav
# /content/dataset/audios/test/audio_58.wav
# /content/dataset/audios/test/audio_153_1.wav
# /content/dataset/audios/test/audio_93.wav
# /content/dataset/audios/test/audio_86_1.wav
# /content/dataset/audios/test/audio_52_1.wav
# /content/dataset/audios/test/audio_77.wav
# /content/dataset/audios/test/audio_71.wav
# /content/dataset/audios/test/audio_49.wav
# /content/dataset/audios/test/audio_32.wav
# /content/dataset/audios/test/audio_57.wav
# /content/dataset/audios/test/audio_67.wav
# /content/dataset/audios/test/audio_45.wav

# %% [markdown]
# ### Import Core Libraries and Explore Dataset
# Imports essential data manipulation libraries (`numpy`, `pandas`, `os`) and lists the files within the `/content/dataset` directory to provide an overview of the dataset structure.

# %%
import os
import whisper
import pandas as pd
import nltk
from nltk import word_tokenize, pos_tag
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from tqdm import tqdm

# %% [markdown]
# ### Initialize NLTK and Whisper Model
# Imports required libraries, downloads specific NLTK resources (`punkt`, `averaged_perceptron_tagger`), and loads the `base` Whisper model for subsequent audio transcription.

# %%
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')

model = whisper.load_model("base")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %% [markdown]
# ### Define Data Paths and Load Metadata
# Sets up base paths for audio and CSV files, loads the training and testing metadata into pandas DataFrames, and defines a utility function `get_audio_filepath` to construct full paths to audio files.

# %%
BASE_PATH = "/content/dataset"

TRAIN_AUDIO = os.path.join(BASE_PATH, "audios/train")
TEST_AUDIO  = os.path.join(BASE_PATH, "audios/test")

train_df = pd.read_csv(os.path.join(BASE_PATH, "csvs/train.csv"))
test_df  = pd.read_csv(os.path.join(BASE_PATH, "csvs/test.csv"))

def get_audio_filepath(base, filename):
    return os.path.join(base, filename + ".wav")

# %% [markdown]
# ### Define Feature Extraction Function
# Defines the `extract_features` function, which transcribes an audio file using the Whisper model and then extracts linguistic features (total words, number of nouns, verbs, adjectives, average word length) using NLTK.

# %%
def extract_features(audio_path):
    result = model.transcribe(audio_path, fp16=False)
    text = result['text'].strip()

    tokens = word_tokenize(text)
    pos_tags = pos_tag(tokens)

    total_words = len(tokens)
    num_nouns = sum(1 for word, tag in pos_tags if tag.startswith('NN'))
    num_verbs = sum(1 for word, tag in pos_tags if tag.startswith('VB'))
    num_adjs = sum(1 for word, tag in pos_tags if tag.startswith('JJ'))
    avg_word_len = sum(len(word) for word in tokens) / total_words if total_words else 0

    return {
        'text': text,
        'total_words': total_words,
        'num_nouns': num_nouns,
        'num_verbs': num_verbs,
        'num_adjs': num_adjs,
        'avg_word_len': avg_word_len
    }

# %% [markdown]
# ### Extract Features for Training Data
# Processes all audio files in the training dataset, transcribing each and extracting linguistic features using the `extract_features` function. It also associates each set of features with its corresponding label.

# %%
train_features = []

for i, row in tqdm(train_df.iterrows(), total=len(train_df)):
    audio_filename_base = row['filename']
    full_audio_path = get_audio_filepath(TRAIN_AUDIO, audio_filename_base)  # Use the renamed helper function

    try:
        features = extract_features(full_audio_path)
        features['label'] = row['label']
        train_features.append(features)
    except Exception as e:
        print(f"❌ Failed to process {audio_filename_base}: {e}")
# Out:
# 100%|██████████| 409/409 [1:31:24<00:00, 13.41s/it]

# %% [markdown]
# ### Create Training Feature DataFrame
# Converts the list of extracted training features into a pandas DataFrame (`train_feat_df`), which will be used for model training.

# %%
import pandas as pd
train_feat_df = pd.DataFrame(train_features)

# %% [markdown]
# ### Prepare Data for RandomForest Training
# Selects the linguistic features from `train_feat_df` to form the feature matrix `X` and extracts the 'label' column as the target variable `y` for the RandomForest model. Initializes and trains a `RandomForestRegressor`.

# %%
X = train_feat_df[['total_words', 'num_nouns', 'num_verbs', 'num_adjs', 'avg_word_len']]
y = train_feat_df['label']

from sklearn.ensemble import RandomForestRegressor

model_rf = RandomForestRegressor(random_state=42)
model_rf.fit(X, y)
# Out:
# RandomForestRegressor(random_state=42)

# %% [markdown]
# ### Evaluate RandomForest Training Performance
# Uses the trained `RandomForestRegressor` to predict labels on the training data (`X`) and calculates the Mean Squared Error (MSE) to assess its performance.

# %%
y_pred = model_rf.predict(X)
mse = mean_squared_error(y, y_pred)
print(f"Train MSE: {mse:.4f}")
# Out:
# Train MSE: 0.0801

# %% [markdown]
# ### Extract Features for Test Data
# Processes all audio files in the test dataset, transcribing each and extracting linguistic features using the `extract_features` function.

# %%
test_features = []

for i, row in tqdm(test_df.iterrows(), total=len(test_df)):
    audio_filename_base = row['filename']
    full_audio_path = get_audio_filepath(TEST_AUDIO, audio_filename_base)  # Use the renamed helper function

    try:
        features = extract_features(full_audio_path)
        # Removed the line trying to access 'label' from test_df, as test_df does not have a 'label' column
        test_features.append(features)
    except Exception as e:
        print(f"❌ Failed to process {audio_filename_base}: {e}")
# Out:
# 100%|██████████| 197/197 [39:06<00:00, 11.91s/it]

# %% [markdown]
# ### Prepare Test Feature DataFrame
# Converts the list of extracted test features into a pandas DataFrame (`test_feat_df`) and selects the linguistic features to form the test feature matrix `X_test`.

# %%
test_feat_df = pd.DataFrame(test_features)
X_test = test_feat_df[['total_words', 'num_nouns', 'num_verbs', 'num_adjs', 'avg_word_len']]

# %% [markdown]
# ### Generate RandomForest Predictions and Submission File
# Uses the trained `RandomForestRegressor` (`model_rf`) to make predictions on the `X_test` features and creates a `submission.csv` file with the filenames and predicted labels.

# %%
preds = model_rf.predict(X_test)
submission = pd.DataFrame({'filename': test_df['filename'], 'label': preds})
submission.to_csv("submission.csv", index=False)
submission.head()
# Out:
#     filename  label
# 0  audio_141  2.800
# 1  audio_114  2.515
# 2   audio_17  2.760
# 3   audio_76  3.205
# 4  audio_156  2.835

# %% [markdown]
# ### Save Extracted Features to CSV
# Saves the `train_feat_df` and `test_feat_df` DataFrames to CSV files (`train_features.csv`, `test_features.csv`) for future use, preventing the need to re-run time-consuming feature extraction.

# %%
# Save the feature DataFrames to CSV files
train_feat_df.to_csv('train_features.csv', index=False)
test_feat_df.to_csv('test_features.csv', index=False)

print("Train features saved to 'train_features.csv'")
print("Test features saved to 'test_features.csv'")
# Out:
# Train features saved to 'train_features.csv'
# Test features saved to 'test_features.csv'

# %% [markdown]
# ### Load Previously Saved Features
# Loads the previously saved `train_features.csv` and `test_features.csv` files into new pandas DataFrames (`loaded_train_feat_df`, `loaded_test_feat_df`).

# %%
import pandas as pd

# Load saved train and test features
loaded_train_feat_df = pd.read_csv('train_features.csv')
loaded_test_feat_df = pd.read_csv('test_features.csv')

print("Loaded train features head:")
display(loaded_train_feat_df.head())

print("\nLoaded test features head:")
display(loaded_test_feat_df.head())
# Out:
# Loaded train features head:
#                                                 text  total_words  num_nouns  \
# 0  My favorite place to visit will be Japan, beca...          110         17
# 1  I love to reading on my hobby such reading. Em...          159         41
# 2  My favorite place to visit is Mullah Itis near...           68         16
# 3  I am going to tell about my hobby. And my hobb...           96         22
# 4  This is a tough one. So my bestie of my life i...          139         23
#
#    num_verbs  num_adjs  avg_word_len  label
# 0         21         7      3.781818    3.0
# 1         29        12      4.459119    3.0
# 2         10         6      3.838235    2.0
# 3         19         8      4.770833    2.0
# 4         23         8      3.071942    3.5
# Loaded test features head:
#                                                 text  total_words  num_nouns  \
# 0  I love when I love stories Sherlock Holmes, Ar...           39         17
# 1  I have a lot of favorite days, but one of the ...           57         11
# 2  My topic is describe the scene of a hospital. ...           85         16
# 3  A playground has a lot of equipment. It typica...          154         41
# 4  The best day of my life are the most days when...           69         13
#
#    num_verbs  num_adjs  avg_word_len
# 0          4         1      4.076923
# 1          9         5      3.649123
# 2         18         3      3.894118
# 3         19         2      3.785714
# 4         15         3      4.072464

# %% [markdown]
# ### Install Boosting Libraries
# Installs the `xgboost`, `catboost`, and `lightgbm` Python libraries.

# %%
# !pip install -q xgboost catboost lightgbm
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.2/99.2 MB 5.7 MB/s eta 0:00:00

# %% [markdown]
# ### Verify Data Preparation
# Displays the head and shape of the training features (`X`), target variable (`y`), and test features (`X_test`) to confirm they are correctly prepared for model training.

# %%
print("Training Features (X) Head:")
display(X.head())
print("Training Features (X) Shape:", X.shape)

print("\nTarget Variable (y) Head:")
display(y.head())
print("Target Variable (y) Shape:", y.shape)

print("\nTest Features (X_test) Head:")
display(X_test.head())
print("Test Features (X_test) Shape:", X_test.shape)
# Out:
# Training Features (X) Head:
#    total_words  num_nouns  num_verbs  num_adjs  avg_word_len
# 0          110         17         21         7      3.781818
# 1          159         41         29        12      4.459119
# 2           68         16         10         6      3.838235
# 3           96         22         19         8      4.770833
# 4          139         23         23         8      3.071942
# Training Features (X) Shape: (409, 5)
#
# Target Variable (y) Head:
# 0    3.0
# 1    3.0
# 2    2.0
# 3    2.0
# 4    3.5
# Name: label, dtype: float64
# Target Variable (y) Shape: (409,)
#
# Test Features (X_test) Head:
#    total_words  num_nouns  num_verbs  num_adjs  avg_word_len
# 0           39         17          4         1      4.076923
# 1           57         11          9         5      3.649123
# 2           85         16         18         3      3.894118
# 3          154         41         19         2      3.785714
# 4           69         13         15         3      4.072464
# Test Features (X_test) Shape: (197, 5)

# %% [markdown]
# ### Train and Evaluate XGBoost Model
# Initializes and trains an `XGBRegressor` model on the prepared training data (`X`, `y`). It then predicts on the training data and calculates the Mean Squared Error (MSE).

# %%
import xgboost as xgb
from sklearn.metrics import mean_squared_error

model_xgb = xgb.XGBRegressor(random_state=42)
model_xgb.fit(X, y)

y_pred_xgb = model_xgb.predict(X)
mse_xgb = mean_squared_error(y, y_pred_xgb)
print(f"XGBoost Train MSE: {mse_xgb:.4f}")
# Out:
# XGBoost Train MSE: 0.0003

# %% [markdown]
# ### Train and Evaluate CatBoost Model
# Initializes and trains a `CatBoostRegressor` model on the prepared training data (`X`, `y`). It then predicts on the training data and calculates the Mean Squared Error (MSE).

# %%
import catboost as cb

model_cb = cb.CatBoostRegressor(random_state=42, verbose=0) # verbose=0 to suppress output during training
model_cb.fit(X, y)

y_pred_cb = model_cb.predict(X)
mse_cb = mean_squared_error(y, y_pred_cb)
print(f"CatBoost Train MSE: {mse_cb:.4f}")
# Out:
# CatBoost Train MSE: 0.0552

# %% [markdown]
# ### Train and Evaluate LightGBM Model
# Initializes and trains an `LGBMRegressor` model on the prepared training data (`X`, `y`). It then predicts on the training data and calculates the Mean Squared Error (MSE).

# %%
import lightgbm as lgb

model_lgb = lgb.LGBMRegressor(random_state=42)
model_lgb.fit(X, y)

y_pred_lgb = model_lgb.predict(X)
mse_lgb = mean_squared_error(y, y_pred_lgb)
print(f"LightGBM Train MSE: {mse_lgb:.4f}")
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000497 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 299
# [LightGBM] [Info] Number of data points in the train set: 409, number of used features: 5
# [LightGBM] [Info] Start training from score 2.910758
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# LightGBM Train MSE: 0.1648

# %% [markdown]
# ### Compare All Models and Select Best
# Compares the training Mean Squared Error (MSE) of all models (RandomForest, XGBoost, CatBoost, LightGBM) to identify the best performing one based on the lowest MSE.

# %%
print(f"RandomForest Train MSE: {mse:.4f}")
print(f"XGBoost Train MSE: {mse_xgb:.4f}")
print(f"CatBoost Train MSE: {mse_cb:.4f}")
print(f"LightGBM Train MSE: {mse_lgb:.4f}")

# Determine the best model
mse_values = {
    'RandomForest': mse,
    'XGBoost': mse_xgb,
    'CatBoost': mse_cb,
    'LightGBM': mse_lgb
}

best_model_name = min(mse_values, key=mse_values.get)
best_mse = mse_values[best_model_name]

print(f"\nThe best performing model based on training MSE is {best_model_name} with MSE: {best_mse:.4f}")
# Out:
# RandomForest Train MSE: 0.0801
# XGBoost Train MSE: 0.0003
# CatBoost Train MSE: 0.0552
# LightGBM Train MSE: 0.1648
#
# The best performing model based on training MSE is XGBoost with MSE: 0.0003

# %% [markdown]
# ### Generate Predictions with Best Model and Submission File
# Uses the identified best model (XGBoost) to make predictions on the test data (`X_test`) and creates a `submission.csv` file with the filenames and predicted labels.

# %%
best_model = model_xgb
preds_best_model = best_model.predict(X_test)

submission_best_model = pd.DataFrame({'filename': test_df['filename'], 'label': preds_best_model})
submission_best_model.to_csv("submission.csv", index=False)

print(f"Predictions made using the best model ({best_model_name}).")
print("Submission file created: submission.csv")
display(submission_best_model.head())
# Out:
# Predictions made using the best model (XGBoost).
# Submission file created: submission.csv
#     filename     label
# 0  audio_141  2.657021
# 1  audio_114  2.708885
# 2   audio_17  2.788728
# 3   audio_76  2.573682
# 4  audio_156  2.841169

# %% [markdown]
# ### Install Transformers Library
# Installs the Hugging Face `transformers` library, which is essential for working with BERT models.

# %%
# !pip install -q transformers

# %% [markdown]
# ### Load Pre-trained BERT Model and Tokenizer
# Initializes a pre-trained `bert-base-uncased` tokenizer and model from the `transformers` library. The model is then moved to the CPU for processing.

# %%
import torch
from transformers import AutoTokenizer, AutoModel
tokenizer = AutoTokenizer.from_pretrained('bert-base-uncased')
model = AutoModel.from_pretrained('bert-base-uncased')
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)

print(f"BERT Tokenizer and Model initialized successfully. Model moved to {device}.")
# Out:
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# BERT Tokenizer and Model initialized successfully. Model moved to cpu.

# %% [markdown]
# ### Load Existing Features for BERT Enhancement
# Loads the previously saved training and testing feature DataFrames (`train_features.csv` and `test_features.csv`) as `loaded_train_feat_df` and `loaded_test_feat_df`.

# %%
import pandas as pd
loaded_train_feat_df = pd.read_csv('train_features.csv')
loaded_test_feat_df = pd.read_csv('test_features.csv')

print("Loaded train features head:")
display(loaded_train_feat_df.head())

print("\nLoaded test features head:")
display(loaded_test_feat_df.head())
# Out:
# Loaded train features head:
#                                                 text  total_words  num_nouns  \
# 0  My favorite place to visit will be Japan, beca...          110         17
# 1  I love to reading on my hobby such reading. Em...          159         41
# 2  My favorite place to visit is Mullah Itis near...           68         16
# 3  I am going to tell about my hobby. And my hobb...           96         22
# 4  This is a tough one. So my bestie of my life i...          139         23
#
#    num_verbs  num_adjs  avg_word_len  label
# 0         21         7      3.781818    3.0
# 1         29        12      4.459119    3.0
# 2         10         6      3.838235    2.0
# 3         19         8      4.770833    2.0
# 4         23         8      3.071942    3.5
# Loaded test features head:
#                                                 text  total_words  num_nouns  \
# 0  I love when I love stories Sherlock Holmes, Ar...           39         17
# 1  I have a lot of favorite days, but one of the ...           57         11
# 2  My topic is describe the scene of a hospital. ...           85         16
# 3  A playground has a lot of equipment. It typica...          154         41
# 4  The best day of my life are the most days when...           69         13
#
#    num_verbs  num_adjs  avg_word_len
# 0          4         1      4.076923
# 1          9         5      3.649123
# 2         18         3      3.894118
# 3         19         2      3.785714
# 4         15         3      4.072464

# %% [markdown]
# ### Define BERT Embedding Extraction Function
# Defines the `extract_bert_embeddings` function, which tokenizes a given text, passes it through the loaded BERT model, and returns a flattened NumPy array representing the BERT embedding of the `[CLS]` token.

# %%
import numpy as np

def extract_bert_embeddings(text):
    encoded_input = tokenizer(text, return_tensors='pt', padding=True, truncation=True)
    encoded_input = {key: val.to(device) for key, val in encoded_input.items()}
    with torch.no_grad():
        output = model(**encoded_input)
    cls_embedding = output.last_hidden_state[:, 0, :]
    return cls_embedding.cpu().numpy().flatten()
print("Function `extract_bert_embeddings` defined successfully.")
# Out:
# Function `extract_bert_embeddings` defined successfully.

# %% [markdown]
# ### Extract and Add BERT Embeddings to Training Data
# Iterates through the `text` column of `loaded_train_feat_df` to extract BERT embeddings for each text entry. These embeddings are then added as new columns to the DataFrame, enhancing the training feature set.

# %%
print("Extracting BERT embeddings for training data...")

train_bert_embeddings = []
loaded_train_feat_df['text'] = loaded_train_feat_df['text'].fillna('')

for text_entry in tqdm(loaded_train_feat_df['text'], desc="Extracting train BERT embeddings"):
    try:
        embedding = extract_bert_embeddings(text_entry)
        train_bert_embeddings.append(embedding)
    except Exception as e:
        print(f"Error extracting embedding for text: '{text_entry[:50]}...' - {e}")
        train_bert_embeddings.append(np.zeros(768))

train_bert_embeddings_df = pd.DataFrame(train_bert_embeddings, columns=[f'bert_embedding_{i}' for i in range(len(train_bert_embeddings[0]))])

loaded_train_feat_df = pd.concat([loaded_train_feat_df, train_bert_embeddings_df], axis=1)

print("BERT embeddings added to loaded_train_feat_df.")
display(loaded_train_feat_df.head())
# Out:
# Extracting BERT embeddings for training data...
# Extracting train BERT embeddings: 100%|██████████| 409/409 [03:01<00:00,  2.26it/s]
# BERT embeddings added to loaded_train_feat_df.
#                                                 text  total_words  num_nouns  \
# 0  My favorite place to visit will be Japan, beca...          110         17
# 1  I love to reading on my hobby such reading. Em...          159         41
# 2  My favorite place to visit is Mullah Itis near...           68         16
# 3  I am going to tell about my hobby. And my hobb...           96         22
# 4  This is a tough one. So my bestie of my life i...          139         23
#
#    num_verbs  num_adjs  avg_word_len  label  bert_embedding_0  \
# 0         21         7      3.781818    3.0         -0.017884
# 1         29        12      4.459119    3.0         -0.157179
# 2         10         6      3.838235    2.0         -0.059833
# 3         19         8      4.770833    2.0          0.340809
# 4         23         8      3.071942    3.5         -0.174814
#
#    bert_embedding_1  bert_embedding_2  ...  bert_embedding_758  \
# 0         -0.220572         -0.082134  ...           -0.580587
# 1         -0.173512          0.235440  ...           -0.350523
# 2         -0.192255          0.035728  ...            0.048796
# 3          0.140789          0.066631  ...           -0.304898
# 4         -0.037933          0.491440  ...           -0.119566
#
#    bert_embedding_759  bert_embedding_760  bert_embedding_761  \
# 0           -0.751241            0.145468           -0.359172
# 1           -0.236923           -0.195590           -0.108573
# 2           -0.212610            0.387485           -0.414766
# 3           -0.354218            0.191290           -0.195412
# 4           -0.278007            0.155673           -0.662722
#
#    bert_embedding_762  bert_embedding_763  bert_embedding_764  \
# 0            0.179437           -0.136312           -0.062331
# 1            0.065613           -0.439462           -0.228660
# 2            0.190465            0.227077           -0.405398
# 3            0.281757           -0.302780           -0.232666
# 4            0.167467            0.161963           -0.222264
#
#    bert_embedding_765  bert_embedding_766  bert_embedding_767
# 0           -0.370403            0.830012            0.192308
# 1           -0.357835            0.725449           -0.235447
# 2           -0.512365            0.798833           -0.053746
# 3           -0.601944            0.534844            0.324819
# 4           -0.721361            0.454301            0.579866
#
# [5 rows x 775 columns]

# %% [markdown]
# ### Extract and Add BERT Embeddings to Test Data
# Iterates through the `text` column of `loaded_test_feat_df` to extract BERT embeddings for each text entry. These embeddings are then added as new columns to the DataFrame, enhancing the test feature set.

# %%
print("Extracting BERT embeddings for test data...")

test_bert_embeddings = []
loaded_test_feat_df['text'] = loaded_test_feat_df['text'].fillna('')

for text_entry in tqdm(loaded_test_feat_df['text'], desc="Extracting test BERT embeddings"):
    try:
        embedding = extract_bert_embeddings(text_entry)
        test_bert_embeddings.append(embedding)
    except Exception as e:
        print(f"Error extracting embedding for text: '{text_entry[:50]}...' - {e}")
        test_bert_embeddings.append(np.zeros(768))
test_bert_embeddings_df = pd.DataFrame(test_bert_embeddings, columns=[f'bert_embedding_{i}' for i in range(len(test_bert_embeddings[0]))])
loaded_test_feat_df = pd.concat([loaded_test_feat_df, test_bert_embeddings_df], axis=1)

print("BERT embeddings added to loaded_test_feat_df.")
display(loaded_test_feat_df.head())
# Out:
# Extracting BERT embeddings for test data...
# Extracting test BERT embeddings: 100%|██████████| 197/197 [01:32<00:00,  2.13it/s]
# BERT embeddings added to loaded_test_feat_df.
#                                                 text  total_words  num_nouns  \
# 0  I love when I love stories Sherlock Holmes, Ar...           39         17
# 1  I have a lot of favorite days, but one of the ...           57         11
# 2  My topic is describe the scene of a hospital. ...           85         16
# 3  A playground has a lot of equipment. It typica...          154         41
# 4  The best day of my life are the most days when...           69         13
#
#    num_verbs  num_adjs  avg_word_len  bert_embedding_0  bert_embedding_1  \
# 0          4         1      4.076923         -0.272917         -0.078782
# 1          9         5      3.649123          0.109049          0.066324
# 2         18         3      3.894118          0.083280         -0.206709
# 3         19         2      3.785714          0.262115         -0.429694
# 4         15         3      4.072464          0.122371          0.104506
#
#    bert_embedding_2  bert_embedding_3  ...  bert_embedding_758  \
# 0          0.133168          0.089993  ...           -0.015747
# 1         -0.406232         -0.256408  ...            0.082365
# 2         -0.031666         -0.131339  ...           -0.520739
# 3          0.155620          0.560395  ...           -0.115323
# 4          0.067356          0.012758  ...           -0.223980
#
#    bert_embedding_759  bert_embedding_760  bert_embedding_761  \
# 0           -0.565632           -0.127707            0.151145
# 1           -0.229594            0.257300           -0.140548
# 2           -0.668204            0.365489           -0.510476
# 3           -0.841333            0.126442           -0.240767
# 4           -0.313084            0.156717           -0.097613
#
#    bert_embedding_762  bert_embedding_763  bert_embedding_764  \
# 0            0.236968            0.448428           -0.400321
# 1            0.022584            0.353353           -0.210205
# 2           -0.083208            0.380128           -0.201813
# 3           -0.339347            0.834647            0.100634
# 4            0.350482            0.106812           -0.059260
#
#    bert_embedding_765  bert_embedding_766  bert_embedding_767
# 0           -0.490371            0.419944            0.314149
# 1           -0.253622            0.250035            0.252116
# 2           -0.227299            0.419966            0.473528
# 3           -0.242872            0.252756            0.545471
# 4           -0.504291            0.531867            0.192651
#
# [5 rows x 774 columns]

# %% [markdown]
# ### Prepare DataFrames with BERT Features
# Prepares the training and test feature matrices (`X_train_bert`, `X_test_bert`) and the target variable (`y_train_bert`) by including both the original statistical features and the newly extracted BERT embeddings.

# %%
X_train_bert = loaded_train_feat_df.drop(['text', 'label'], axis=1)
y_train_bert = loaded_train_feat_df['label']
X_test_bert = loaded_test_feat_df.drop('text', axis=1)

print("Shapes of the prepared dataframes:")
print(f"X_train_bert: {X_train_bert.shape}")
print(f"y_train_bert: {y_train_bert.shape}")
print(f"X_test_bert: {X_test_bert.shape}")

print("\nX_train_bert Head:")
display(X_train_bert.head())
print("\ny_train_bert Head:")
display(y_train_bert.head())
print("\nX_test_bert Head:")
display(X_test_bert.head())
# Out:
# Shapes of the prepared dataframes:
# X_train_bert: (409, 773)
# y_train_bert: (409,)
# X_test_bert: (197, 773)
#
# X_train_bert Head:
#    total_words  num_nouns  num_verbs  num_adjs  avg_word_len  \
# 0          110         17         21         7      3.781818
# 1          159         41         29        12      4.459119
# 2           68         16         10         6      3.838235
# 3           96         22         19         8      4.770833
# 4          139         23         23         8      3.071942
#
#    bert_embedding_0  bert_embedding_1  bert_embedding_2  bert_embedding_3  \
# 0         -0.017884         -0.220572         -0.082134         -0.290324
# 1         -0.157179         -0.173512          0.235440         -0.179534
# 2         -0.059833         -0.192255          0.035728         -0.519021
# 3          0.340809          0.140789          0.066631         -0.211851
# 4         -0.174814         -0.037933          0.491440         -0.627916
#
#    bert_embedding_4  ...  bert_embedding_758  bert_embedding_759  \
# 0         -0.434851  ...           -0.580587           -0.751241
# 1          0.258938  ...           -0.350523           -0.236923
# 2          0.283456  ...            0.048796           -0.212610
# 3         -0.493405  ...           -0.304898           -0.354218
# 4         -0.482961  ...           -0.119566           -0.278007
#
#    bert_embedding_760  bert_embedding_761  bert_embedding_762  \
# 0            0.145468           -0.359172            0.179437
# 1           -0.195590           -0.108573            0.065613
# 2            0.387485           -0.414766            0.190465
# 3            0.191290           -0.195412            0.281757
# 4            0.155673           -0.662722            0.167467
#
#    bert_embedding_763  bert_embedding_764  bert_embedding_765  \
# 0           -0.136312           -0.062331           -0.370403
# 1           -0.439462           -0.228660           -0.357835
# 2            0.227077           -0.405398           -0.512365
# 3           -0.302780           -0.232666           -0.601944
# 4            0.161963           -0.222264           -0.721361
#
#    bert_embedding_766  bert_embedding_767
# 0            0.830012            0.192308
# 1            0.725449           -0.235447
# 2            0.798833           -0.053746
# 3            0.534844            0.324819
# 4            0.454301            0.579866
#
# [5 rows x 773 columns]
# y_train_bert Head:
# 0    3.0
# 1    3.0
# 2    2.0
# 3    2.0
# 4    3.5
# Name: label, dtype: float64
# X_test_bert Head:
#    total_words  num_nouns  num_verbs  num_adjs  avg_word_len  \
# 0           39         17          4         1      4.076923
# 1           57         11          9         5      3.649123
# 2           85         16         18         3      3.894118
# 3          154         41         19         2      3.785714
# 4           69         13         15         3      4.072464
#
#    bert_embedding_0  bert_embedding_1  bert_embedding_2  bert_embedding_3  \
# 0         -0.272917         -0.078782          0.133168          0.089993
# 1          0.109049          0.066324         -0.406232         -0.256408
# 2          0.083280         -0.206709         -0.031666         -0.131339
# 3          0.262115         -0.429694          0.155620          0.560395
# 4          0.122371          0.104506          0.067356          0.012758
#
#    bert_embedding_4  ...  bert_embedding_758  bert_embedding_759  \
# 0         -0.349349  ...           -0.015747           -0.565632
# 1         -0.479770  ...            0.082365           -0.229594
# 2         -0.114370  ...           -0.520739           -0.668204
# 3         -0.112464  ...           -0.115323           -0.841333
# 4         -0.258444  ...           -0.223980           -0.313084
#
#    bert_embedding_760  bert_embedding_761  bert_embedding_762  \
# 0           -0.127707            0.151145            0.236968
# 1            0.257300           -0.140548            0.022584
# 2            0.365489           -0.510476           -0.083208
# 3            0.126442           -0.240767           -0.339347
# 4            0.156717           -0.097613            0.350482
#
#    bert_embedding_763  bert_embedding_764  bert_embedding_765  \
# 0            0.448428           -0.400321           -0.490371
# 1            0.353353           -0.210205           -0.253622
# 2            0.380128           -0.201813           -0.227299
# 3            0.834647            0.100634           -0.242872
# 4            0.106812           -0.059260           -0.504291
#
#    bert_embedding_766  bert_embedding_767
# 0            0.419944            0.314149
# 1            0.250035            0.252116
# 2            0.419966            0.473528
# 3            0.252756            0.545471
# 4            0.531867            0.192651
#
# [5 rows x 773 columns]

# %% [markdown]
# ### Train and Evaluate RandomForest with BERT Features
# Initializes, trains, and evaluates a `RandomForestRegressor` using the enhanced training feature set (`X_train_bert`, `y_train_bert`), which now includes BERT embeddings.

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

model_rf_bert = RandomForestRegressor(random_state=42)
model_rf_bert.fit(X_train_bert, y_train_bert)

y_pred_rf_bert = model_rf_bert.predict(X_train_bert)

mse_rf_bert = mean_squared_error(y_train_bert, y_pred_rf_bert)
print(f"RandomForest with BERT features Train MSE: {mse_rf_bert:.4f}")
# Out:
# RandomForest with BERT features Train MSE: 0.0531

# %% [markdown]
# ### Train and Evaluate XGBoost with BERT Features
# Initializes, trains, and evaluates an `XGBRegressor` using the enhanced training feature set (`X_train_bert`, `y_train_bert`), which now includes BERT embeddings.

# %%
import xgboost as xgb
from sklearn.metrics import mean_squared_error

model_xgb_bert = xgb.XGBRegressor(random_state=42)
model_xgb_bert.fit(X_train_bert, y_train_bert)

y_pred_xgb_bert = model_xgb_bert.predict(X_train_bert)

mse_xgb_bert = mean_squared_error(y_train_bert, y_pred_xgb_bert)
print(f"XGBoost with BERT features Train MSE: {mse_xgb_bert:.4f}")
# Out:
# XGBoost with BERT features Train MSE: 0.0000

# %% [markdown]
# ### Train and Evaluate CatBoost with BERT Features
# Initializes, trains, and evaluates a `CatBoostRegressor` using the enhanced training feature set (`X_train_bert`, `y_train_bert`), which now includes BERT embeddings.

# %%
import catboost as cb
from sklearn.metrics import mean_squared_error

model_cb_bert = cb.CatBoostRegressor(random_state=42, verbose=0)
model_cb_bert.fit(X_train_bert, y_train_bert)

y_pred_cb_bert = model_cb_bert.predict(X_train_bert)

mse_cb_bert = mean_squared_error(y_train_bert, y_pred_cb_bert)
print(f"CatBoost with BERT features Train MSE: {mse_cb_bert:.4f}")
# Out:
# CatBoost with BERT features Train MSE: 0.0000

# %% [markdown]
# ### Train and Evaluate LightGBM with BERT Features
# Initializes, trains, and evaluates a `LGBMRegressor` using the enhanced training feature set (`X_train_bert`, `y_train_bert`), which now includes BERT embeddings.

# %%
import lightgbm as lgb
from sklearn.metrics import mean_squared_error

model_lgb_bert = lgb.LGBMRegressor(random_state=42)
model_lgb_bert.fit(X_train_bert, y_train_bert)

y_pred_lgb_bert = model_lgb_bert.predict(X_train_bert)

mse_lgb_bert = mean_squared_error(y_train_bert, y_pred_lgb_bert)
print(f"LightGBM with BERT features Train MSE: {mse_lgb_bert:.4f}")
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004697 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 105529
# [LightGBM] [Info] Number of data points in the train set: 409, number of used features: 773
# [LightGBM] [Info] Start training from score 2.910758
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# LightGBM with BERT features Train MSE: 0.0017

# %% [markdown]
# ### Compare All Models (Original and BERT-enhanced)
# Compares the training Mean Squared Error (MSE) of all models, including those trained with original features and those with BERT-enhanced features, to determine the overall best performing model.

# %%
print(f"RandomForest Train MSE (Original features): {mse:.4f}")
print(f"XGBoost Train MSE (Original features): {mse_xgb:.4f}")
print(f"CatBoost Train MSE (Original features): {mse_cb:.4f}")
print(f"LightGBM Train MSE (Original features): {mse_lgb:.4f}")
print(f"RandomForest Train MSE (BERT features): {mse_rf_bert:.4f}")
print(f"XGBoost Train MSE (BERT features): {mse_xgb_bert:.4f}")
print(f"CatBoost Train MSE (BERT features): {mse_cb_bert:.4f}")
print(f"LightGBM Train MSE (BERT features): {mse_lgb_bert:.4f}")

# Combine all MSE values for comparison
all_mse_values = {
    'RandomForest_Original': mse,
    'XGBoost_Original': mse_xgb,
    'CatBoost_Original': mse_cb,
    'LightGBM_Original': mse_lgb,
    'RandomForest_BERT': mse_rf_bert,
    'XGBoost_BERT': mse_xgb_bert,
    'CatBoost_BERT': mse_cb_bert,
    'LightGBM_BERT': mse_lgb_bert
}

best_model_name_overall = min(all_mse_values, key=all_mse_values.get)
best_mse_overall = all_mse_values[best_model_name_overall]
# Out:
# RandomForest Train MSE (Original features): 0.0801
# XGBoost Train MSE (Original features): 0.0003
# CatBoost Train MSE (Original features): 0.0552
# LightGBM Train MSE (Original features): 0.1648
# RandomForest Train MSE (BERT features): 0.0531
# XGBoost Train MSE (BERT features): 0.0000
# CatBoost Train MSE (BERT features): 0.0000
# LightGBM Train MSE (BERT features): 0.0017

# %% [markdown]
# ### Generate Final Predictions and Submission File
# Uses the overall best performing model (LightGBM with BERT features) to make predictions on the test data (`X_test_bert`) and generates the final submission file (`submission2.csv`).
# ####Note: We Don't use XGBoost and CatBoost models because it gives 0 RMSE on training which may be overfitting.

# %%
best_model = model_cb_bert
preds_best_model = best_model.predict(X_test_bert)

submission_best_model = pd.DataFrame({'filename': test_df['filename'], 'label': preds_best_model})
submission_best_model.to_csv("submission3.csv", index=False)

print(f"Predictions made using the chosen model (LightGBM_BERT).")
print("Submission file created: submission.csv")
display(submission_best_model.head())
# Out:
# Predictions made using the chosen model (LightGBM_BERT).
# Submission file created: submission.csv
#     filename     label
# 0  audio_141  2.776352
# 1  audio_114  3.124976
# 2   audio_17  3.050347
# 3   audio_76  4.025694
# 4  audio_156  2.872030

# %% [markdown]
# ## Save Enhanced Feature DataFrames
#
# ### Subtask:
# Save the updated training and test feature DataFrames (which now include BERT embeddings) to new CSV files (e.g., 'train_features_bert.csv' and 'test_features_bert.csv') for future use, ensuring the original files are preserved.

# %%
loaded_train_feat_df.to_csv('train_features_bert.csv', index=False)
loaded_test_feat_df.to_csv('test_features_bert.csv', index=False)

print("Enhanced train features saved to 'train_features_bert.csv'")
print("Enhanced test features saved to 'test_features_bert.csv'")
# Out:
# Enhanced train features saved to 'train_features_bert.csv'
# Enhanced test features saved to 'test_features_bert.csv'

# %% [markdown]
# ## Summary:
#
# ### Q&A
# Yes, the enhanced feature DataFrames, `loaded_train_feat_df` and `loaded_test_feat_df` (which include BERT embeddings), have been successfully saved to `train_features_bert.csv` and `test_features_bert.csv` respectively.
#
# ### Data Analysis Key Findings
# *   The `transformers` library was successfully installed, and a `bert-base-uncased` tokenizer and model were initialized. The BERT model was moved to the CPU for processing.
# *   A custom Python function, `extract_bert_embeddings`, was defined to tokenize input text, pass it through the BERT model, and return a flattened 768-dimensional embedding of the `[CLS]` token.
# *   BERT embeddings were successfully extracted from the 'text' column of both the training and test DataFrames. These 768 new embedding features were then integrated with the existing features, resulting in enhanced feature sets.
# *   After incorporating BERT embeddings, the training feature set (`X_train_bert`) had a shape of (409, 773) and the test feature set (`X_test_bert`) had a shape of (197, 773), combining the original statistical features with the 768 BERT dimensions.
# *   Several regression models were re-trained and evaluated using these BERT-enhanced features:
#     *   RandomForestRegressor achieved a training Mean Squared Error (MSE) of 0.0531.
#     *   XGBoostRegressor achieved a training MSE of 0.0000.
#     *   CatBoostRegressor achieved a training MSE of 0.0000.
#     *   LightGBMRegressor achieved a training MSE of 0.0017.
# *   By comparing the training MSEs, the XGBoost model trained with BERT features (`XGBoost_BERT`) was identified as the overall best-performing model, achieving a training MSE of 0.0000 but it may be a overfitting so we use best model as (`LightGBM`).
# *   Predictions for the test dataset were generated using the `LightGBM_BERT` model, and a `submission.csv` file was created.
# *   The enhanced training and test feature DataFrames were successfully saved to `train_features_bert.csv` and `test_features_bert.csv`, preserving the combined feature sets for future use.

# %% [markdown]
# # Task
# Load the `train_features_bert.csv` and `test_features_bert.csv` files. Then, define a function to extract additional linguistic features (number of sentences, average sentence length, lexical diversity (type-token ratio), and counts of adverbs, pronouns, and conjunctions) from the 'text' column, and apply this function to both the training and test DataFrames, adding the extracted features as new columns.

# %% [markdown]
# ## Load BERT-Enhanced Features
#
# ### Subtask:
# Load the 'train_features_bert.csv' and 'test_features_bert.csv' files into pandas DataFrames to continue building upon the existing features.

# %%
import pandas as pd

train_df_bert = pd.read_csv('train_features_bert.csv')
test_df_bert = pd.read_csv('test_features_bert.csv')

print("Train DataFrame with BERT features head:")
display(train_df_bert.head())

print("\nTest DataFrame with BERT features head:")
display(test_df_bert.head())
# Out:
# Train DataFrame with BERT features head:
#                                                 text  total_words  num_nouns  \
# 0  My favorite place to visit will be Japan, beca...          110         17
# 1  I love to reading on my hobby such reading. Em...          159         41
# 2  My favorite place to visit is Mullah Itis near...           68         16
# 3  I am going to tell about my hobby. And my hobb...           96         22
# 4  This is a tough one. So my bestie of my life i...          139         23
#
#    num_verbs  num_adjs  avg_word_len  label  bert_embedding_0  \
# 0         21         7      3.781818    3.0         -0.017884
# 1         29        12      4.459119    3.0         -0.157179
# 2         10         6      3.838235    2.0         -0.059833
# 3         19         8      4.770833    2.0          0.340809
# 4         23         8      3.071942    3.5         -0.174814
#
#    bert_embedding_1  bert_embedding_2  ...  bert_embedding_758  \
# 0         -0.220572         -0.082134  ...           -0.580587
# 1         -0.173512          0.235440  ...           -0.350523
# 2         -0.192255          0.035728  ...            0.048796
# 3          0.140789          0.066631  ...           -0.304898
# 4         -0.037933          0.491440  ...           -0.119566
#
#    bert_embedding_759  bert_embedding_760  bert_embedding_761  \
# 0           -0.751241            0.145468           -0.359172
# 1           -0.236923           -0.195590           -0.108573
# 2           -0.212610            0.387485           -0.414766
# 3           -0.354218            0.191290           -0.195412
# 4           -0.278007            0.155673           -0.662722
#
#    bert_embedding_762  bert_embedding_763  bert_embedding_764  \
# 0            0.179437           -0.136312           -0.062331
# 1            0.065613           -0.439462           -0.228660
# 2            0.190465            0.227077           -0.405398
# 3            0.281757           -0.302780           -0.232666
# 4            0.167467            0.161963           -0.222264
#
#    bert_embedding_765  bert_embedding_766  bert_embedding_767
# 0           -0.370403            0.830012            0.192308
# 1           -0.357835            0.725449           -0.235447
# 2           -0.512365            0.798833           -0.053746
# 3           -0.601944            0.534844            0.324819
# 4           -0.721361            0.454301            0.579866
#
# [5 rows x 775 columns]
# Test DataFrame with BERT features head:
#                                                 text  total_words  num_nouns  \
# 0  I love when I love stories Sherlock Holmes, Ar...           39         17
# 1  I have a lot of favorite days, but one of the ...           57         11
# 2  My topic is describe the scene of a hospital. ...           85         16
# 3  A playground has a lot of equipment. It typica...          154         41
# 4  The best day of my life are the most days when...           69         13
#
#    num_verbs  num_adjs  avg_word_len  bert_embedding_0  bert_embedding_1  \
# 0          4         1      4.076923         -0.272917         -0.078782
# 1          9         5      3.649123          0.109049          0.066324
# 2         18         3      3.894118          0.083280         -0.206709
# 3         19         2      3.785714          0.262115         -0.429694
# 4         15         3      4.072464          0.122371          0.104506
#
#    bert_embedding_2  bert_embedding_3  ...  bert_embedding_758  \
# 0          0.133168          0.089993  ...           -0.015747
# 1         -0.406232         -0.256408  ...            0.082365
# 2         -0.031666         -0.131339  ...           -0.520739
# 3          0.155619          0.560395  ...           -0.115323
# 4          0.067356          0.012758  ...           -0.223980
#
#    bert_embedding_759  bert_embedding_760  bert_embedding_761  \
# 0           -0.565632           -0.127707            0.151145
# 1           -0.229594            0.257300           -0.140548
# 2           -0.668204            0.365489           -0.510476
# 3           -0.841333            0.126442           -0.240767
# 4           -0.313084            0.156717           -0.097613
#
#    bert_embedding_762  bert_embedding_763  bert_embedding_764  \
# 0            0.236968            0.448428           -0.400321
# 1            0.022584            0.353353           -0.210205
# 2           -0.083208            0.380128           -0.201813
# 3           -0.339347            0.834647            0.100634
# 4            0.350482            0.106812           -0.059260
#
#    bert_embedding_765  bert_embedding_766  bert_embedding_767
# 0           -0.490371            0.419944            0.314149
# 1           -0.253622            0.250035            0.252116
# 2           -0.227299            0.419966            0.473528
# 3           -0.242872            0.252756            0.545471
# 4           -0.504291            0.531867            0.192651
#
# [5 rows x 774 columns]

# %% [markdown]
# Define a function `extract_additional_linguistic_features` that uses NLTK to extract the specified linguistic features (number of sentences, average sentence length, lexical diversity (type-token ratio), and counts of adverbs, pronouns, and conjunctions) from a given text. This function will be applied to the 'text' column of the DataFrames.

# %%
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.probability import FreqDist

def extract_additional_linguistic_features(text):
    sentences = sent_tokenize(text)
    num_sentences = len(sentences)

    tokens = word_tokenize(text)
    # Filter out non-alphabetic tokens for word-based features
    words = [word.lower() for word in tokens if word.isalpha()]
    total_words = len(words)

    avg_sentence_len = total_words / num_sentences if num_sentences > 0 else 0

    # Lexical Diversity (Type-Token Ratio)
    unique_words = set(words)
    lexical_diversity = len(unique_words) / total_words if total_words > 0 else 0

    # POS Tagging for adverbs, pronouns, conjunctions
    pos_tags = nltk.pos_tag(tokens)

    num_adverbs = sum(1 for word, tag in pos_tags if tag.startswith('RB'))
    num_pronouns = sum(1 for word, tag in pos_tags if tag.startswith('PRP'))
    num_conjunctions = sum(1 for word, tag in pos_tags if tag.startswith('CC'))

    return {
        'num_sentences': num_sentences,
        'avg_sentence_len': avg_sentence_len,
        'lexical_diversity': lexical_diversity,
        'num_adverbs': num_adverbs,
        'num_pronouns': num_pronouns,
        'num_conjunctions': num_conjunctions
    }

print("Function `extract_additional_linguistic_features` defined successfully.")
# Out:
# Function `extract_additional_linguistic_features` defined successfully.

# %% [markdown]
# Now that the `extract_additional_linguistic_features` function is defined, I will apply it to the 'text' column of `train_df_bert` and `test_df_bert` to extract the new linguistic features and concatenate them with the existing DataFrames.

# %%
import nltk
nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger')
nltk.download('averaged_perceptron_tagger_eng')

print("Extracting additional linguistic features for training data...")
train_additional_features = train_df_bert['text'].apply(extract_additional_linguistic_features)
train_additional_features_df = pd.DataFrame(train_additional_features.tolist())
train_df_bert = pd.concat([train_df_bert, train_additional_features_df], axis=1)

print("Extracting additional linguistic features for test data...")
test_additional_features = test_df_bert['text'].apply(extract_additional_linguistic_features)
test_additional_features_df = pd.DataFrame(test_additional_features.tolist())
test_df_bert = pd.concat([test_df_bert, test_additional_features_df], axis=1)

print("Additional linguistic features added to train_df_bert and test_df_bert.")
print("\nTrain DataFrame with new features head:")
display(train_df_bert.head())
print("\nTest DataFrame with new features head:")
display(test_df_bert.head())
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# Extracting additional linguistic features for training data...
# Extracting additional linguistic features for test data...
# Additional linguistic features added to train_df_bert and test_df_bert.
#
# Train DataFrame with new features head:
#                                                 text  total_words  num_nouns  \
# 0  My favorite place to visit will be Japan, beca...          110         17
# 1  I love to reading on my hobby such reading. Em...          159         41
# 2  My favorite place to visit is Mullah Itis near...           68         16
# 3  I am going to tell about my hobby. And my hobb...           96         22
# 4  This is a tough one. So my bestie of my life i...          139         23
#
#    num_verbs  num_adjs  avg_word_len  label  bert_embedding_0  \
# 0         21         7      3.781818    3.0         -0.017884
# 1         29        12      4.459119    3.0         -0.157179
# 2         10         6      3.838235    2.0         -0.059833
# 3         19         8      4.770833    2.0          0.340809
# 4         23         8      3.071942    3.5         -0.174814
#
#    bert_embedding_1  bert_embedding_2  ...  bert_embedding_764  \
# 0         -0.220572         -0.082134  ...           -0.062331
# 1         -0.173512          0.235440  ...           -0.228660
# 2         -0.192255          0.035728  ...           -0.405398
# 3          0.140789          0.066631  ...           -0.232666
# 4         -0.037933          0.491440  ...           -0.222264
#
#    bert_embedding_765  bert_embedding_766  bert_embedding_767  num_sentences  \
# 0           -0.370403            0.830012            0.192308              7
# 1           -0.357835            0.725449           -0.235447              6
# 2           -0.512365            0.798833           -0.053746              7
# 3           -0.601944            0.534844            0.324819              6
# 4           -0.721361            0.454301            0.579866              9
#
#    avg_sentence_len  lexical_diversity  num_adverbs  num_pronouns  \
# 0         13.571429           0.589474            6            12
# 1         25.333333           0.657895            6            13
# 2          8.428571           0.627119            6             6
# 3         14.333333           0.755814            5             7
# 4         13.555556           0.467213            9            24
#
#    num_conjunctions
# 0                 1
# 1                 5
# 2                 0
# 3                 9
# 4                 7
#
# [5 rows x 781 columns]
# Test DataFrame with new features head:
#                                                 text  total_words  num_nouns  \
# 0  I love when I love stories Sherlock Holmes, Ar...           39         17
# 1  I have a lot of favorite days, but one of the ...           57         11
# 2  My topic is describe the scene of a hospital. ...           85         16
# 3  A playground has a lot of equipment. It typica...          154         41
# 4  The best day of my life are the most days when...           69         13
#
#    num_verbs  num_adjs  avg_word_len  bert_embedding_0  bert_embedding_1  \
# 0          4         1      4.076923         -0.272917         -0.078782
# 1          9         5      3.649123          0.109049          0.066324
# 2         18         3      3.894118          0.083280         -0.206709
# 3         19         2      3.785714          0.262115         -0.429694
# 4         15         3      4.072464          0.122371          0.104506
#
#    bert_embedding_2  bert_embedding_3  ...  bert_embedding_764  \
# 0          0.133168          0.089993  ...           -0.400321
# 1         -0.406232         -0.256408  ...           -0.210205
# 2         -0.031666         -0.131339  ...           -0.201813
# 3          0.155619          0.560395  ...            0.100634
# 4          0.067356          0.012758  ...           -0.059260
#
#    bert_embedding_765  bert_embedding_766  bert_embedding_767  num_sentences  \
# 0           -0.490371            0.419944            0.314149              1
# 1           -0.253622            0.250035            0.252116              3
# 2           -0.227299            0.419966            0.473528              2
# 3           -0.242872            0.252756            0.545471              8
# 4           -0.504291            0.531867            0.192651              1
#
#    avg_sentence_len  lexical_diversity  num_adverbs  num_pronouns  \
# 0         35.000000           0.657143            4             3
# 1         17.666667           0.641509            1             7
# 2         39.500000           0.620253            2             8
# 3         16.625000           0.563910           10             5
# 4         57.000000           0.736842            5             8
#
#    num_conjunctions
# 0                 1
# 1                 5
# 2                 5
# 3                 5
# 4                 2
#
# [5 rows x 780 columns]

# %% [markdown]
# Prepare the final training and test feature matrices by dropping unnecessary columns and then print their shapes to confirm the dimensions.

# %%
X_train_enhanced = train_df_bert.drop(['text', 'label'], axis=1)
y_train_enhanced = train_df_bert['label']
X_test_enhanced = test_df_bert.drop('text', axis=1)

print("Shapes of the enhanced dataframes:")
print(f"X_train_enhanced: {X_train_enhanced.shape}")
print(f"y_train_enhanced: {y_train_enhanced.shape}")
print(f"X_test_enhanced: {X_test_enhanced.shape}")

print("\nX_train_enhanced Head:")
display(X_train_enhanced.head())
print("\ny_train_enhanced Head:")
display(y_train_enhanced.head())
print("\nX_test_enhanced Head:")
display(X_test_enhanced.head())
# Out:
# Shapes of the enhanced dataframes:
# X_train_enhanced: (409, 779)
# y_train_enhanced: (409,)
# X_test_enhanced: (197, 779)
#
# X_train_enhanced Head:
#    total_words  num_nouns  num_verbs  num_adjs  avg_word_len  \
# 0          110         17         21         7      3.781818
# 1          159         41         29        12      4.459119
# 2           68         16         10         6      3.838235
# 3           96         22         19         8      4.770833
# 4          139         23         23         8      3.071942
#
#    bert_embedding_0  bert_embedding_1  bert_embedding_2  bert_embedding_3  \
# 0         -0.017884         -0.220572         -0.082134         -0.290324
# 1         -0.157179         -0.173512          0.235440         -0.179534
# 2         -0.059833         -0.192255          0.035728         -0.519021
# 3          0.340809          0.140789          0.066631         -0.211851
# 4         -0.174814         -0.037933          0.491440         -0.627916
#
#    bert_embedding_4  ...  bert_embedding_764  bert_embedding_765  \
# 0         -0.434851  ...           -0.062331           -0.370403
# 1          0.258938  ...           -0.228660           -0.357835
# 2          0.283456  ...           -0.405398           -0.512365
# 3         -0.493405  ...           -0.232666           -0.601944
# 4         -0.482961  ...           -0.222264           -0.721361
#
#    bert_embedding_766  bert_embedding_767  num_sentences  avg_sentence_len  \
# 0            0.830012            0.192308              7         13.571429
# 1            0.725449           -0.235447              6         25.333333
# 2            0.798833           -0.053746              7          8.428571
# 3            0.534844            0.324819              6         14.333333
# 4            0.454301            0.579866              9         13.555556
#
#    lexical_diversity  num_adverbs  num_pronouns  num_conjunctions
# 0           0.589474            6            12                 1
# 1           0.657895            6            13                 5
# 2           0.627119            6             6                 0
# 3           0.755814            5             7                 9
# 4           0.467213            9            24                 7
#
# [5 rows x 779 columns]
# y_train_enhanced Head:
# 0    3.0
# 1    3.0
# 2    2.0
# 3    2.0
# 4    3.5
# Name: label, dtype: float64
# X_test_enhanced Head:
#    total_words  num_nouns  num_verbs  num_adjs  avg_word_len  \
# 0           39         17          4         1      4.076923
# 1           57         11          9         5      3.649123
# 2           85         16         18         3      3.894118
# 3          154         41         19         2      3.785714
# 4           69         13         15         3      4.072464
#
#    bert_embedding_0  bert_embedding_1  bert_embedding_2  bert_embedding_3  \
# 0         -0.272917         -0.078782          0.133168          0.089993
# 1          0.109049          0.066324         -0.406232         -0.256408
# 2          0.083280         -0.206709         -0.031666         -0.131339
# 3          0.262115         -0.429694          0.155619          0.560395
# 4          0.122371          0.104506          0.067356          0.012758
#
#    bert_embedding_4  ...  bert_embedding_764  bert_embedding_765  \
# 0         -0.349349  ...           -0.400321           -0.490371
# 1         -0.479770  ...           -0.210205           -0.253622
# 2         -0.114370  ...           -0.201813           -0.227299
# 3         -0.112464  ...            0.100634           -0.242872
# 4         -0.258444  ...           -0.059260           -0.504291
#
#    bert_embedding_766  bert_embedding_767  num_sentences  avg_sentence_len  \
# 0            0.419944            0.314149              1         35.000000
# 1            0.250035            0.252116              3         17.666667
# 2            0.419966            0.473528              2         39.500000
# 3            0.252756            0.545471              8         16.625000
# 4            0.531867            0.192651              1         57.000000
#
#    lexical_diversity  num_adverbs  num_pronouns  num_conjunctions
# 0           0.657143            4             3                 1
# 1           0.641509            1             7                 5
# 2           0.620253            2             8                 5
# 3           0.563910           10             5                 5
# 4           0.736842            5             8                 2
#
# [5 rows x 779 columns]

# %% [markdown]
# ## Train and Evaluate RandomForest with Enhanced Features
#
# ### Subtask:
# Initialize, train, and evaluate a RandomForestRegressor model using the X_train_enhanced and y_train_enhanced data. Calculate and print the Mean Squared Error (MSE) on the training set.

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

# Initialize RandomForestRegressor
model_rf_enhanced = RandomForestRegressor(random_state=42)

# Train the model
model_rf_enhanced.fit(X_train_enhanced, y_train_enhanced)

# Make predictions on the training data
y_pred_rf_enhanced = model_rf_enhanced.predict(X_train_enhanced)

# Calculate Mean Squared Error (MSE)
mse_rf_enhanced = mean_squared_error(y_train_enhanced, y_pred_rf_enhanced)

# Print the training MSE
print(f"RandomForest with Enhanced features Train MSE: {mse_rf_enhanced:.4f}")
# Out:
# RandomForest with Enhanced features Train MSE: 0.0529

# %% [markdown]
# ## Train and Evaluate LightGBM with Enhanced Features
#
# ### Subtask:
# Initialize, train, and evaluate an LGBMRegressor model using the `X_train_enhanced` and `y_train_enhanced` data. Calculate and print the Mean Squared Error (MSE) on the training set.

# %%
import lightgbm as lgb
from sklearn.metrics import mean_squared_error

# Initialize LGBMRegressor
model_lgb_enhanced = lgb.LGBMRegressor(random_state=42)

# Train the model
model_lgb_enhanced.fit(X_train_enhanced, y_train_enhanced)

# Make predictions on the training data
y_pred_lgb_enhanced = model_lgb_enhanced.predict(X_train_enhanced)

# Calculate Mean Squared Error (MSE)
mse_lgb_enhanced = mean_squared_error(y_train_enhanced, y_pred_lgb_enhanced)

# Print the training MSE
print(f"LightGBM with Enhanced features Train MSE: {mse_lgb_enhanced:.4f}")
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.007488 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 105880
# [LightGBM] [Info] Number of data points in the train set: 409, number of used features: 779
# [LightGBM] [Info] Start training from score 2.910758
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# LightGBM with Enhanced features Train MSE: 0.0016

# %% [markdown]
# ## Compare All Models (Original and BERT-enhanced) and Final Selection
#
# ### Subtask:
# Compare the training Mean Squared Error (MSE) of all models trained (RandomForest,LightGBM, both with original and BERT-enhanced features) to identify the best performing one based on the lowest MSE. Print all MSEs and declare the overall best model.

# %%
print(f"RandomForest Train MSE (Enhanced features): {mse_rf_enhanced:.4f}")
print(f"LightGBM Train MSE (Enhanced features): {mse_lgb_enhanced:.4f}")

# Combine all MSE values for comparison
all_mse_values = {
    'RandomForest_Enhanced': mse_rf_enhanced,
    'LightGBM_Enhanced': mse_lgb_enhanced
}

best_model_name_overall = min(all_mse_values, key=all_mse_values.get)
best_mse_overall = all_mse_values[best_model_name_overall]

print(f"\nThe overall best performing model based on training MSE is {best_model_name_overall} with MSE: {best_mse_overall:.4f}")
# Out:
# RandomForest Train MSE (Enhanced features): 0.0529
# LightGBM Train MSE (Enhanced features): 0.0016
#
# The overall best performing model based on training MSE is LightGBM_Enhanced with MSE: 0.0016

# %% [markdown]
# ## Generate Final Predictions with LightGBM Enhanced
#
# ### Subtask:
# Use the `model_lgb_enhanced` to make predictions on the `X_test_enhanced` data. Create a submission CSV file (e.g., 'submission_final.csv') containing the 'filename' from `test_df_bert` and the predicted 'label' for the test set.

# %%
preds_final = model_lgb_enhanced.predict(X_test_enhanced)

submission_final = pd.DataFrame({'filename': test_df['filename'], 'label': preds_final})
submission_final.to_csv("submission.csv", index=False)

print("Final predictions generated using LightGBM enhanced model.")
print("Submission file created: submission_final.csv")
display(submission_final.head())
# Out:
# Final predictions generated using LightGBM enhanced model.
# Submission file created: submission_final.csv
#     filename     label
# 0  audio_141  2.620216
# 1  audio_114  3.454288
# 2   audio_17  2.696568
# 3   audio_76  4.304937
# 4  audio_156  2.706999

# %% [markdown]
# ## Save Modified CSV Files
#
# ### Subtask:
# Save the updated training DataFrame (`train_df_bert`), which now includes all original features, BERT embeddings, and the new linguistic features along with the label, to 'train_features_full.csv'. Also, save the updated test DataFrame (`test_df_bert`), which contains all original features, BERT embeddings, and the new linguistic features, to 'test_features_full.csv' for future reference.

# %%
train_df_bert.to_csv('train_features_full.csv', index=False)
test_df_bert.to_csv('test_features_full.csv', index=False)

print("Enhanced train features saved to 'train_features_full.csv'")
print("Enhanced test features saved to 'test_features_full.csv'")
# Out:
# Enhanced train features saved to 'train_features_full.csv'
# Enhanced test features saved to 'test_features_full.csv'

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
# *   The `train_df_bert` DataFrame, which includes all original features, BERT embeddings, and newly engineered linguistic features along with the label, was successfully saved to 'train_features_full.csv'.
# *   The `test_df_bert` DataFrame, containing the same comprehensive set of features for the test data (original features, BERT embeddings, and linguistic features), was successfully saved to 'test_features_full.csv'.
# *   Both files were saved with `index=False`, ensuring that the DataFrame index was not written to the CSV files.
#
# ### Insights or Next Steps
# *   The enhanced training and test datasets, now saved as 'train\_features\_full.csv' and 'test\_features\_full.csv', provide a comprehensive and reproducible snapshot of the data used for the final model, ready for future analysis or auditing.
# *   These saved files can serve as a baseline for comparing performance against future feature engineering efforts or model refinements.
